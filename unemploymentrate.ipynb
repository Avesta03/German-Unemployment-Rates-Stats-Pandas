# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('1991-2021rates.csv', parse_dates=True)

# %%
print(df.head())
# Out:
#    year  unemployment rate  annual change
# 0  1991               5.32           1.00
# 1  1992               6.32           1.00
# 2  1993               7.68           1.36
# 3  1994               8.73           1.05
# 4  1995               8.16          -0.57

# %%
['year', 'unemployment rate']

small_df = df[['year','unemployment rate']]

# %%
df.head()
# Out:
#    year  unemployment rate  annual change
# 0  1991               5.32           1.00
# 1  1992               6.32           1.00
# 2  1993               7.68           1.36
# 3  1994               8.73           1.05
# 4  1995               8.16          -0.57

# %%
small_df.head()
# Out:
#    year  unemployment rate
# 0  1991               5.32
# 1  1992               6.32
# 2  1993               7.68
# 3  1994               8.73
# 4  1995               8.16

# %%
plt.plot(small_df['year'], small_df['unemployment rate'], color='red')
plt.title('Unemployment Rate From 1991 to 2021')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.show()
